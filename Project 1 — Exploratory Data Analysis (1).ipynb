# %%
# Data source: https://data.cityofnewyork.us/Health/New-York-City-Leading-Causes-of-Death/jb7j-dtam
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

pd.set_option('display.mpl_style', 'default')
plt.rcParams['figure.figsize'] = (15, 5)

# %%
df = pd.read_csv('data/nycdeath.csv')

# %%
#Key exploration objectives:
#1)How death type differs by race in 2011
#2)How does gender affect leading death type in 2011 
#3)How has leading death type changed from 2007 to 2011

# %%
df.describe()
# Out:
#               Year        Count    Percent
# count   960.000000   960.000000  960.00000
# mean   2009.009375   248.215625    3.71250
# std       1.421904   722.988702    8.12793
# min    2007.000000     5.000000    0.00000
# 25%    2008.000000    20.000000    0.00000
# 50%    2009.000000    54.000000    1.00000
# 75%    2010.000000   156.000000    3.00000
# max    2011.000000  7050.000000   49.00000

# %%
#Group by year to assess 
gryear = df.groupby('Year').aggregate(sum)  
gryear.describe()
# Out:
#               Count     Percent
# count      5.000000    5.000000
# mean   47657.400000  712.800000
# std     1365.047545   11.166915
# min    46069.000000  694.000000
# 25%    46523.000000  712.000000
# 50%    47693.000000  716.000000
# 75%    48875.000000  721.000000
# max    49127.000000  721.000000

# %%
gryear.plot(kind='bar')

# %%
#only want to examine 2011 data/subset
year_2011 = df[df.Year==2011]
#Subsetting the data by year to focus on 2011 data for some parts of my analysis

# %%
#Create new DataFrame from 2011 data; sort by count to uncover top causes of death
#QUESTION 1: How death type differs by race in 2011
ct_2011 = year_2011[['Count', 'Ethnicity', 'Sex', 'CauseofDeath']]
sort_ct_2011=ct_2011.sort(columns='Count', axis=0, ascending=False)

# %%
api_data = sort_ct_2011[sort_ct_2011.Ethnicity == 'ASIAN & PACIFIC ISLANDER']
api_data.head(6)
#Asian subset: we can see cancer is the leading cause of death for Asians, but heart disease is the leading cause of death for all the other races that were sampled
# Out:
#     Count                 Ethnicity     Sex             CauseofDeath
# 77    550  ASIAN & PACIFIC ISLANDER    MALE      MALIGNANT NEOPLASMS
# 57    454  ASIAN & PACIFIC ISLANDER  FEMALE      MALIGNANT NEOPLASMS
# 73    452  ASIAN & PACIFIC ISLANDER    MALE        DISEASES OF HEART
# 53    402  ASIAN & PACIFIC ISLANDER  FEMALE        DISEASES OF HEART
# 47     98  ASIAN & PACIFIC ISLANDER  FEMALE  CEREBROVASCULAR DISEASE
# 75     94  ASIAN & PACIFIC ISLANDER    MALE  INFLUENZA AND PNEUMONIA

# %%
his_data = sort_ct_2011[sort_ct_2011.Ethnicity == 'HISPANIC']
his_data.head(6)
#Hispanic subset
# Out:
#      Count Ethnicity     Sex             CauseofDeath
# 98    1348  HISPANIC  FEMALE        DISEASES OF HEART
# 122   1201  HISPANIC    MALE        DISEASES OF HEART
# 127   1144  HISPANIC    MALE      MALIGNANT NEOPLASMS
# 103   1085  HISPANIC  FEMALE      MALIGNANT NEOPLASMS
# 101    218  HISPANIC  FEMALE  INFLUENZA AND PNEUMONIA
# 125    209  HISPANIC    MALE  INFLUENZA AND PNEUMONIA

# %%
nhb_data = sort_ct_2011[sort_ct_2011.Ethnicity == 'NON-HISPANIC BLACK']
nhb_data.head(6)
#Black subset: Diabetes was the third leading cause of death in non-hispanic blacks, but not as high for other ethnicities
# Out:
#      Count           Ethnicity     Sex         CauseofDeath
# 149   2243  NON-HISPANIC BLACK  FEMALE    DISEASES OF HEART
# 153   1918  NON-HISPANIC BLACK  FEMALE  MALIGNANT NEOPLASMS
# 174   1840  NON-HISPANIC BLACK    MALE    DISEASES OF HEART
# 179   1590  NON-HISPANIC BLACK    MALE  MALIGNANT NEOPLASMS
# 148    410  NON-HISPANIC BLACK  FEMALE    DIABETES MELLITUS
# 173    307  NON-HISPANIC BLACK    MALE    DIABETES MELLITUS

# %%
nhw_data = sort_ct_2011[sort_ct_2011.Ethnicity == 'NON-HISPANIC WHITE']
nhw_data.head(6)
#White subset
# Out:
#      Count           Ethnicity     Sex             CauseofDeath
# 200   5016  NON-HISPANIC WHITE  FEMALE        DISEASES OF HEART
# 224   4220  NON-HISPANIC WHITE    MALE        DISEASES OF HEART
# 205   3373  NON-HISPANIC WHITE  FEMALE      MALIGNANT NEOPLASMS
# 229   3222  NON-HISPANIC WHITE    MALE      MALIGNANT NEOPLASMS
# 203    696  NON-HISPANIC WHITE  FEMALE  INFLUENZA AND PNEUMONIA
# 227    646  NON-HISPANIC WHITE    MALE  INFLUENZA AND PNEUMONIA

# %%
#Now, let's see how
HIV_data = sort_ct_2011[sort_ct_2011.CauseofDeath == 'HUMAN IMMUNODEFICIENCY VIRUS DISEASE']
HIV_data
#Wow! If you are non-hispanic black male, you have more than triple the chance of dying from HIV than non-hispanic white males.
#Additionally, if you are a hispanic  male, you have more than double the chance of dying from HIV than non-hispanic white males.
# Out:
#      Count           Ethnicity     Sex                          CauseofDeath
# 176    277  NON-HISPANIC BLACK    MALE  HUMAN IMMUNODEFICIENCY VIRUS DISEASE
# 124    162            HISPANIC    MALE  HUMAN IMMUNODEFICIENCY VIRUS DISEASE
# 151    144  NON-HISPANIC BLACK  FEMALE  HUMAN IMMUNODEFICIENCY VIRUS DISEASE
# 226     75  NON-HISPANIC WHITE    MALE  HUMAN IMMUNODEFICIENCY VIRUS DISEASE
# 100     70            HISPANIC  FEMALE  HUMAN IMMUNODEFICIENCY VIRUS DISEASE
# 202     19  NON-HISPANIC WHITE  FEMALE  HUMAN IMMUNODEFICIENCY VIRUS DISEASE

# %% [markdown]
# pct_2011 — want to narrow down my DataFrame to only my columns of interest

# %% [markdown]
# Now, using a pivot table to analyze aggregate changes to causes of death over the years

# %%
#QUESTION 2)How does gender affect leading death type in 2011 

sex_male = year_2011[year_2011.Sex=='MALE']
#sex_male_all=sex_male.sort(columns='Count', axis=0, ascending=False)

pivoted_sex = year_2011.pivot_table(values='Count',
                 columns='Sex',
                 index='CauseofDeath',
                 aggfunc='sum')
pivoted_sex
# Out:
# Sex                                               FEMALE  MALE
# CauseofDeath
# ACCIDENTS EXCEPT DRUG POISONING                      356   646
# ALZHEIMERS DISEASE                                   435   184
# ANEMIAS                                               33    34
# AORTIC ANEURYSM AND DISSECTION                        58    99
# ASSAULT (HOMICIDE)                                    98   423
# ATHEROSCLEROSIS                                       93    50
# BENIGN AND UNCERTAIN NEOPLASMS                       142   121
# CARDIOVASCULAR DISORDERS IN PERINATAL PERIOD          24   NaN
# CEREBROVASCULAR DISEASE                             1024   716
# CHOLELITHIASIS AND DISORDERS OF GALLBLADDER           21   NaN
# CHRONIC LIVER DISEASE AND CIRRHOSIS                  167   375
# CHRONIC LOWER RESPIRATORY DISEASES                   917   841
# CONGENITAL MALFORMATIONS,DEFORMATIONS                 96   136
# DIABETES MELLITUS                                    910   825
# DISEASES OF HEART                                   9009  7713
# ESSENTIAL HYPERTENSION AND RENAL DISEASES            553   402
# HUMAN IMMUNODEFICIENCY VIRUS DISEASE                 233   514
# INFLUENZA AND PNEUMONIA                             1271  1192
# INTENTIONAL SELF-HARM (SUICIDE)                      112   373
# MALIGNANT NEOPLASMS                                 6830  6506
# MENTAL DISORDERS DUE TO USE OF ALCOHOL                36   164
# NEPHRITIS, NEPHROTIC SYNDROME AND NEPHROSIS          219   226
# PARKINSONS DISEASE                                    76   109
# PEPTIC ULCER                                          46    48
# PREGNANCY, CHILDBIRTH AND THE PUERPERIUM              25   NaN
# PSYCH. SUBSTANCE USE & ACCIDENTAL DRUG POISONING     209   539
# SEPTICEMIA                                           191   184
# SHORT GESTATION/LBW                                   43    49
# TUBERCULOSIS                                         NaN    10
# VIRAL HEPATITIS                                      110   253

# %%
pivoted_sex.plot(figsize=(30, 6))
#Chronic Lower Respiratory disease 4th leading cause males, 5th in females
#Cerebrovascular disease 4th leading in women, 6th leading in men
#Assault/homicide 10th leading cause in men, 18th in women
#Alzheimer’s 8th leading cause in females, 16th in men

# %%
#QUESTION 3)How has leading death type changed from 2007 to 2011
pivoted_df = df.pivot_table(values='Count',
                 columns='Year',
                 index='CauseofDeath',
                 aggfunc='sum')
pivoted_df
#Snapshot/overview of how death type has changed over the years
# Out:
# Year                                               2007   2008   2009   2010  \
# CauseofDeath
# ACCIDENTS EXCEPT DRUG POISONING                    1016   1026    983    913
# ALZHEIMERS DISEASE                                  276    363    514    574
# ANEMIAS                                              37     23     34     44
# AORTIC ANEURYSM AND DISSECTION                      222    120    145    145
# ASSAULT (HOMICIDE)                                  503    524    488    531
# ATHEROSCLEROSIS                                     171    171    231    197
# BENIGN AND UNCERTAIN NEOPLASMS                      242    215    244    262
# CARDIOVASCULAR DISORDERS IN PERINATAL PERIOD         76     55     33     29
# CEREBROVASCULAR DISEASE                            1547   1486   1432   1568
# CHOLELITHIASIS AND DISORDERS OF GALLBLADDER          27     26     17     35
# CHRONIC LIVER DISEASE AND CIRRHOSIS                 445    532    481    515
# CHRONIC LOWER RESPIRATORY DISEASES                 1411   1589   1511   1692
# CONGENITAL MALFORMATIONS,DEFORMATIONS               232    283    238    228
# DIABETES MELLITUS                                  1535   1620   1678   1687
# DISEASES OF HEART                                 21195  20918  19803  17687
# ESSENTIAL HYPERTENSION AND RENAL DISEASES           782    879    926   1035
# HUMAN IMMUNODEFICIENCY VIRUS DISEASE               1095   1054    919    817
# INFLUENZA AND PNEUMONIA                            2219   2267   2238   2442
# INTENTIONAL SELF-HARM (SUICIDE)                     470    461    470    491
# MALIGNANT NEOPLASMS                               13104  12897  13061  13199
# MENTAL DISORDERS DUE TO USE OF ALCOHOL              211    198    206    178
# NEPHRITIS, NEPHROTIC SYNDROME AND NEPHROSIS         430    378    365    483
# PARKINSONS DISEASE                                  100    137    151    175
# PEPTIC ULCER                                         71     84     66     78
# PNEUMONITIS DUE TO SOLIDS AND LIQUIDS               NaN      8    NaN    NaN
# PREGNANCY, CHILDBIRTH AND THE PUERPERIUM             33     36     34     29
# PSYCH. SUBSTANCE USE & ACCIDENTAL DRUG POISONING    834    716    685    648
# RESPIRATORY DISTRESS OF NEWBORN                       7     18    NaN    NaN
# SEPTICEMIA                                          387    320    245    354
# SHORT GESTATION/LBW                                  92    102    106    139
# TUBERCULOSIS                                        NaN    NaN    NaN      5
# VIRAL HEPATITIS                                     357    369    389    343
#
# Year                                               2011
# CauseofDeath
# ACCIDENTS EXCEPT DRUG POISONING                    1002
# ALZHEIMERS DISEASE                                  619
# ANEMIAS                                              67
# AORTIC ANEURYSM AND DISSECTION                      157
# ASSAULT (HOMICIDE)                                  521
# ATHEROSCLEROSIS                                     143
# BENIGN AND UNCERTAIN NEOPLASMS                      263
# CARDIOVASCULAR DISORDERS IN PERINATAL PERIOD         24
# CEREBROVASCULAR DISEASE                            1740
# CHOLELITHIASIS AND DISORDERS OF GALLBLADDER          21
# CHRONIC LIVER DISEASE AND CIRRHOSIS                 542
# CHRONIC LOWER RESPIRATORY DISEASES                 1758
# CONGENITAL MALFORMATIONS,DEFORMATIONS               232
# DIABETES MELLITUS                                  1735
# DISEASES OF HEART                                 16722
# ESSENTIAL HYPERTENSION AND RENAL DISEASES           955
# HUMAN IMMUNODEFICIENCY VIRUS DISEASE                747
# INFLUENZA AND PNEUMONIA                            2463
# INTENTIONAL SELF-HARM (SUICIDE)                     485
# MALIGNANT NEOPLASMS                               13336
# MENTAL DISORDERS DUE TO USE OF ALCOHOL              200
# NEPHRITIS, NEPHROTIC SYNDROME AND NEPHROSIS         445
# PARKINSONS DISEASE                                  185
# PEPTIC ULCER                                         94
# PNEUMONITIS DUE TO SOLIDS AND LIQUIDS               NaN
# PREGNANCY, CHILDBIRTH AND THE PUERPERIUM             25
# PSYCH. SUBSTANCE USE & ACCIDENTAL DRUG POISONING    748
# RESPIRATORY DISTRESS OF NEWBORN                     NaN
# SEPTICEMIA                                          375
# SHORT GESTATION/LBW                                  92
# TUBERCULOSIS                                         10
# VIRAL HEPATITIS                                     363

# %%
#Heart disease gradually declined (went from 21195 in 2007 to 16722 in 2011)
pivoted_df.plot(figsize(20,5))
pivoted_df.plot(kind='bar')
