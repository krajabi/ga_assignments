# %%
# Data source: https://data.cityofnewyork.us/Health/New-York-City-Leading-Causes-of-Death/jb7j-dtam
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

pd.set_option('display.mpl_style', 'default')
plt.rcParams['figure.figsize'] = (15, 5)

# %% [markdown]
# ## df = pd.read_csv('data/nycdeath.csv')
# df.describe()

# %%
#Group by year to assess 
gryear = df.groupby('Year').aggregate(sum)  
gryear.describe()
gryear.plot(kind='bar')

# %%
year_2011 = df[df.Year==2011]
year_2011.head()
#Subsetting the data by year to focus on 2011 data for some parts of my analysis

# %%
#Create new DataFrame from 2011 data; sort by count to uncover top causes of death
ct_2011 = year_2011[['Count', 'Ethnicity', 'Sex', 'Cause of Death']]
sort_ct_2011=ct_2011.sort(columns='Count', axis=0, ascending=False)
sort_ct_2011.head()
#Great...but now we need to aggregate all deaths by ethnicity
# Out:
#      Count           Ethnicity     Sex       Cause of Death
# 200   5016  NON-HISPANIC WHITE  FEMALE    DISEASES OF HEART
# 224   4220  NON-HISPANIC WHITE    MALE    DISEASES OF HEART
# 205   3373  NON-HISPANIC WHITE  FEMALE  MALIGNANT NEOPLASMS
# 229   3222  NON-HISPANIC WHITE    MALE  MALIGNANT NEOPLASMS
# 149   2243  NON-HISPANIC BLACK  FEMALE    DISEASES OF HEART

# %%
#grouping by ethnicity to narrow down how death type differs by race
eth_2011 = year_2011.groupby('Ethnicity', sort = True)
eth_2011.median()
#eth_2011.head()
#max min etc.
#cause of deaths per ethnicity
#total deaths per ethnicity
#Normalize data set by cause of death per ethnicity / total deaths per ethnicity
# Out:
#                           Year  Count  Percent
# Ethnicity
# ASIAN & PACIFIC ISLANDER  2011   16.5        1
# HISPANIC                  2011   50.0        1
# NON-HISPANIC BLACK        2011   56.0        1
# NON-HISPANIC WHITE        2011   77.0        1

# %% [markdown]
# pct_2011 — want to narrow down my DataFrame to only my columns of interest

# %%
#eth_2011.sort(columns='Percent', axis=0, ascending=False)
# Out:
#      Percent                 Ethnicity  \
# 200       37        NON-HISPANIC WHITE
# 224       35        NON-HISPANIC WHITE
# 149       30        NON-HISPANIC BLACK
# 77        30  ASIAN & PACIFIC ISLANDER
# 98        30                  HISPANIC
# 57        30  ASIAN & PACIFIC ISLANDER
# 174       28        NON-HISPANIC BLACK
# 229       27        NON-HISPANIC WHITE
# 53        26  ASIAN & PACIFIC ISLANDER
# 153       26        NON-HISPANIC BLACK
# 205       25        NON-HISPANIC WHITE
# 73        25  ASIAN & PACIFIC ISLANDER
# 122       25                  HISPANIC
# 103       24                  HISPANIC
# 179       24        NON-HISPANIC BLACK
# 127       23                  HISPANIC
# 55         6  ASIAN & PACIFIC ISLANDER
# 47         6  ASIAN & PACIFIC ISLANDER
# 148        6        NON-HISPANIC BLACK
# 203        5        NON-HISPANIC WHITE
# 101        5                  HISPANIC
# 173        5        NON-HISPANIC BLACK
# 75         5  ASIAN & PACIFIC ISLANDER
# 227        5        NON-HISPANIC WHITE
# 177        4        NON-HISPANIC BLACK
# 176        4        NON-HISPANIC BLACK
# 111        4                  HISPANIC
# 97         4                  HISPANIC
# 197        4        NON-HISPANIC WHITE
# 121        4                  HISPANIC
# ..       ...                       ...
# 161        0        NON-HISPANIC BLACK
# 131        0                  HISPANIC
# 88         0                  HISPANIC
# 157        0        NON-HISPANIC BLACK
# 156        0        NON-HISPANIC BLACK
# 134        0                  HISPANIC
# 154        0        NON-HISPANIC BLACK
# 138        0        NON-HISPANIC BLACK
# 139        0        NON-HISPANIC BLACK
# 141        0        NON-HISPANIC BLACK
# 172        0        NON-HISPANIC BLACK
# 114        0                  HISPANIC
# 113        0                  HISPANIC
# 109        0                  HISPANIC
# 89         0                  HISPANIC
# 195        0        NON-HISPANIC WHITE
# 90         0                  HISPANIC
# 91         0                  HISPANIC
# 147        0        NON-HISPANIC BLACK
# 191        0        NON-HISPANIC WHITE
# 190        0        NON-HISPANIC WHITE
# 189        0        NON-HISPANIC WHITE
# 92         0                  HISPANIC
# 96         0                  HISPANIC
# 185        0        NON-HISPANIC BLACK
# 102        0                  HISPANIC
# 182        0        NON-HISPANIC BLACK
# 105        0                  HISPANIC
# 106        0                  HISPANIC
# 192        0        NON-HISPANIC WHITE
#
#                                    Cause of Death
# 200                             DISEASES OF HEART
# 224                             DISEASES OF HEART
# 149                             DISEASES OF HEART
# 77                            MALIGNANT NEOPLASMS
# 98                              DISEASES OF HEART
# 57                            MALIGNANT NEOPLASMS
# 174                             DISEASES OF HEART
# 229                           MALIGNANT NEOPLASMS
# 53                              DISEASES OF HEART
# 153                           MALIGNANT NEOPLASMS
# 205                           MALIGNANT NEOPLASMS
# 73                              DISEASES OF HEART
# 122                             DISEASES OF HEART
# 103                           MALIGNANT NEOPLASMS
# 179                           MALIGNANT NEOPLASMS
# 127                           MALIGNANT NEOPLASMS
# 55                        INFLUENZA AND PNEUMONIA
# 47                        CEREBROVASCULAR DISEASE
# 148                             DIABETES MELLITUS
# 203                       INFLUENZA AND PNEUMONIA
# 101                       INFLUENZA AND PNEUMONIA
# 173                             DIABETES MELLITUS
# 75                        INFLUENZA AND PNEUMONIA
# 227                       INFLUENZA AND PNEUMONIA
# 177                       INFLUENZA AND PNEUMONIA
# 176          HUMAN IMMUNODEFICIENCY VIRUS DISEASE
# 111               ACCIDENTS EXCEPT DRUG POISONING
# 97                              DIABETES MELLITUS
# 197            CHRONIC LOWER RESPIRATORY DISEASES
# 121                             DIABETES MELLITUS
# ..                                            ...
# 161                               VIRAL HEPATITIS
# 131                                  PEPTIC ULCER
# 88                 AORTIC ANEURYSM AND DISSECTION
# 157      PREGNANCY, CHILDBIRTH AND THE PUERPERIUM
# 156                                  PEPTIC ULCER
# 134                           SHORT GESTATION/LBW
# 154        MENTAL DISORDERS DUE TO USE OF ALCOHOL
# 138                                       ANEMIAS
# 139                AORTIC ANEURYSM AND DISSECTION
# 141                               ATHEROSCLEROSIS
# 172         CONGENITAL MALFORMATIONS,DEFORMATIONS
# 114                AORTIC ANEURYSM AND DISSECTION
# 113                                       ANEMIAS
# 109                           SHORT GESTATION/LBW
# 89                             ASSAULT (HOMICIDE)
# 195   CHOLELITHIASIS AND DISORDERS OF GALLBLADDER
# 90                                ATHEROSCLEROSIS
# 91                 BENIGN AND UNCERTAIN NEOPLASMS
# 147         CONGENITAL MALFORMATIONS,DEFORMATIONS
# 191                            ASSAULT (HOMICIDE)
# 190                AORTIC ANEURYSM AND DISSECTION
# 189                                       ANEMIAS
# 92   CARDIOVASCULAR DISORDERS IN PERINATAL PERIOD
# 96          CONGENITAL MALFORMATIONS,DEFORMATIONS
# 185                           SHORT GESTATION/LBW
# 102               INTENTIONAL SELF-HARM (SUICIDE)
# 182                                  PEPTIC ULCER
# 105                            PARKINSONS DISEASE
# 106      PREGNANCY, CHILDBIRTH AND THE PUERPERIUM
# 192                               ATHEROSCLEROSIS
#
# [196 rows x 3 columns]

# %%
gbd = df.groupby('Cause of Death')

# %%
pivoted_df = df.pivot_table(values='Percent',
                 columns='Year',
                 index='Cause of Death',
                 aggfunc='sum')

# %% [markdown]
# Now, using a pivot table to analyze aggregate changes to causes of death over the years

# %%
pivoted_df
# Out:
# Year                                              2007  2008  2009  2010  2011
# Cause of Death
# ACCIDENTS EXCEPT DRUG POISONING                     16    18    16    15    17
# ALZHEIMERS DISEASE                                   4     3     8     9    11
# ANEMIAS                                              0     0     0     0     0
# AORTIC ANEURYSM AND DISSECTION                       2     0     1     1     0
# ASSAULT (HOMICIDE)                                   8     8     8    10     7
# ATHEROSCLEROSIS                                      0     1     3     1     0
# BENIGN AND UNCERTAIN NEOPLASMS                       3     2     3     4     5
# CARDIOVASCULAR DISORDERS IN PERINATAL PERIOD         0     0     0     0     0
# CEREBROVASCULAR DISEASE                             28    26    25    30    29
# CHOLELITHIASIS AND DISORDERS OF GALLBLADDER          0     0     0     0     0
# CHRONIC LIVER DISEASE AND CIRRHOSIS                  6     8     6     9    10
# CHRONIC LOWER RESPIRATORY DISEASES                  20    24    22    25    26
# CONGENITAL MALFORMATIONS,DEFORMATIONS                3     6     5     5     2
# DIABETES MELLITUS                                   28    28    29    30    29
# DISEASES OF HEART                                  287   285   280   254   236
# ESSENTIAL HYPERTENSION AND RENAL DISEASES           14    14    15    18    15
# HUMAN IMMUNODEFICIENCY VIRUS DISEASE                18    17    15    14    12
# INFLUENZA AND PNEUMONIA                             34    35    36    38    38
# INTENTIONAL SELF-HARM (SUICIDE)                      8     8     7     9    10
# MALIGNANT NEOPLASMS                                206   196   207   207   209
# MENTAL DISORDERS DUE TO USE OF ALCOHOL               4     3     3     3     3
# NEPHRITIS, NEPHROTIC SYNDROME AND NEPHROSIS          8     7     8     8     8
# PARKINSONS DISEASE                                   0     0     2     1     2
# PEPTIC ULCER                                         0     0     0     0     0
# PNEUMONITIS DUE TO SOLIDS AND LIQUIDS              NaN     0   NaN   NaN   NaN
# PREGNANCY, CHILDBIRTH AND THE PUERPERIUM             0     0     0     0     0
# PSYCH. SUBSTANCE USE & ACCIDENTAL DRUG POISONING    11    11    10    10    10
# RESPIRATORY DISTRESS OF NEWBORN                      0     0   NaN   NaN   NaN
# SEPTICEMIA                                           6     5     4     8     8
# SHORT GESTATION/LBW                                  0     0     0     1     0
# TUBERCULOSIS                                       NaN   NaN   NaN     0     1
# VIRAL HEPATITIS                                      7     7     8     6     6

# %%
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x12ce86650>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12cef2a10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x12d129750>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12cf8bdd0>]], dtype=object)

# %%
df.boxplot()
plt.figure(figsize=(8, 6), dpi=80)

# %%
sns.set_style() # sets seaborn "white" to the default matplotlib style
plt.figure(figsize=(8, 6), dpi=80)
plt.subplot(1, 1, 1)
plt.hist(df.g, bins=20)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-75-479bd88957ff> in <module>()
#       2 plt.figure(figsize=(8, 6), dpi=80)
#       3 plt.subplot(1, 1, 1)
# ----> 4 plt.hist(df.g, bins=20)
#
# /Users/Kiyan/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    1945                 return self[name]
#    1946             raise AttributeError("'%s' object has no attribute '%s'" %
# -> 1947                                  (type(self).__name__, name))
#    1948
#    1949     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'g'

# %%
ethnicity = df['Ethnicity']
year = df['Year']

# %%
# using plot and the '.' notation.
plt.figure(figsize=(8, 6), dpi=80)
plt.plot(ethnicity, year, '.')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-93501b40e68d> in <module>()
#       1 # using plot and the '.' notation.
#       2 plt.figure(figsize=(8, 6), dpi=80)
# ----> 3 plt.plot(ethnicity, year, '.')
#
# /Users/Kiyan/anaconda/lib/python2.7/site-packages/matplotlib/pyplot.pyc in plot(*args, **kwargs)
#    3097         ax.hold(hold)
#    3098     try:
# -> 3099         ret = ax.plot(*args, **kwargs)
#    3100         draw_if_interactive()
#    3101     finally:
#
# /Users/Kiyan/anaconda/lib/python2.7/site-packages/matplotlib/axes/_axes.pyc in plot(self, *args, **kwargs)
#    1373
#    1374         for line in self._get_lines(*args, **kwargs):
# -> 1375             self.add_line(line)
#    1376             lines.append(line)
#    1377
#
# /Users/Kiyan/anaconda/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in add_line(self, line)
#    1484             line.set_clip_path(self.patch)
#    1485
# -> 1486         self._update_line_limits(line)
#    1487         if not line.get_label():
#    1488             line.set_label('_line%d' % len(self.lines))
#
# /Users/Kiyan/anaconda/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in _update_line_limits(self, line)
#    1495         Figures out the data limit of the given line, updating self.dataLim.
#    1496         """
# -> 1497         path = line.get_path()
#    1498         if path.vertices.size == 0:
#    1499             return
#
# /Users/Kiyan/anaconda/lib/python2.7/site-packages/matplotlib/lines.pyc in get_path(self)
#     869         """
#     870         if self._invalidy or self._invalidx:
# --> 871             self.recache()
#     872         return self._path
#     873
#
# /Users/Kiyan/anaconda/lib/python2.7/site-packages/matplotlib/lines.pyc in recache(self, always)
#     570                 x = ma.asarray(xconv, np.float_)
#     571             else:
# --> 572                 x = np.asarray(xconv, np.float_)
#     573             x = x.ravel()
#     574         else:
#
# /Users/Kiyan/anaconda/lib/python2.7/site-packages/numpy/core/numeric.pyc in asarray(a, dtype, order)
#     460
#     461     """
# --> 462     return array(a, dtype, copy=False, order=order)
#     463
#     464 def asanyarray(a, dtype=None, order=None):
#
# ValueError: could not convert string to float: NON-HISPANIC BLACK
