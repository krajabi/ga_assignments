# %%
# %pylab inline
import numpy as np
from numpy.random import randn
import pandas as pd
from scipy import stats
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
from __future__ import division

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
pd.options.display.mpl_style = 'default'
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
bike = pd.read_csv('data/bikeshare.csv', header=0, na_values='?')

# %%
bike.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0        1  2011-01-01       1   0     1   0        0        6           0           1  0.24  0.2879  0.81          0       3          13   16
# 1        2  2011-01-01       1   0     1   1        0        6           0           1  0.22  0.2727  0.80          0       8          32   40
# 2        3  2011-01-01       1   0     1   2        0        6           0           1  0.22  0.2727  0.80          0       5          27   32
# 3        4  2011-01-01       1   0     1   3        0        6           0           1  0.24  0.2879  0.75          0       3          10   13
# 4        5  2011-01-01       1   0     1   4        0        6           0           1  0.24  0.2879  0.75          0       0           1    1

# %%
bike_by_day = bike.groupby('weekday')

# %%
bike_by_day.describe()
# Out:
#                      atemp       casual          cnt      holiday           hr          hum       instant         mnth   registered       season         temp   weathersit    windspeed   workingday           yr
# weekday
# 0       count  2502.000000  2502.000000  2502.000000  2502.000000  2502.000000  2502.000000   2502.000000  2502.000000  2502.000000  2502.000000  2502.000000  2502.000000  2502.000000  2502.000000  2502.000000
#         mean      0.465507    56.163469   177.468825     0.000000    11.555156     0.627994   8697.580735     6.487210   121.305356     2.490408     0.483821     1.362110     0.188093     0.000000     0.507994
#         std       0.175384    68.090663   168.167710     0.000000     6.916186     0.185472   5062.506448     3.466126   105.972899     1.122143     0.194458     0.605165     0.119804     0.000000     0.500036
# ...

# %% [markdown]
# This shows us a daily stats breakdown for all the various metrics that were collected.

# %%
bike_by_hour = bike.groupby('hr')

# %%
bike_by_hour.describe()
# Out:
#                atemp      casual         cnt     holiday         hum       instant        mnth  registered      season        temp  weathersit     weekday   windspeed  workingday          yr
# hr
# 0  count  726.000000  726.000000  726.000000  726.000000  726.000000    726.000000  726.000000  726.000000  726.000000  726.000000  726.000000  726.000000  726.000000  726.000000  726.000000
#    mean     0.451105   10.158402   53.898072    0.028926    0.691019   8677.683196    6.534435   43.739669    2.500000    0.467410    1.398072    3.004132    0.161758    0.683196    0.502755
#    std      0.158755   10.667953   42.307910    0.167713    0.165626   5025.922087    3.444664   34.019585    1.108898    0.176550    0.619184    2.007224    0.109649    0.465551    0.500337
#    min      0.030300    0.000000    2.000000    0.000000    0.000000      1.000000    1.000000    0.000000    1.000000    0.040000    1.000000    0.000000    0.000000    0.000000    0.000000
# ...

# %% [markdown]
# This shows us an hourly stats breakdown for all the various metrics that were collected.

# %%
pivoted_bike_monthly = bike.pivot_table(values=['temp', 'atemp'],
                 columns='yr',
                 index='mnth',
                 aggfunc='mean')

# %%
pivoted_bike_monthly
# Out:
#           temp               atemp
# yr           0         1         0         1
# mnth
# 1     0.197413  0.275007  0.203758  0.274954
# 2     0.283975  0.315434  0.285730  0.314586
# 3     0.331233  0.449529  0.324879  0.438714
# 4     0.471015  0.469025  0.456624  0.457596
# 5     0.577231  0.612366  0.550814  0.580510
# 6     0.693083  0.675111  0.646559  0.629932
# 7     0.758575  0.752366  0.710660  0.697528
# 8     0.705554  0.711801  0.655650  0.647534
# 9     0.612915  0.620083  0.568591  0.590053
# 10    0.469879  0.505339  0.458702  0.489875
# 11    0.402197  0.336156  0.399196  0.335437
# 12    0.325290  0.323046  0.330032  0.322565

# %% [markdown]
# Pivoted_bike_monthly shows us YoY differences in climate

# %%
plt.hist(bike.temp)
# Out:
# (array([  117.,   953.,  2444.,  2913.,  2433.,  2684.,  3150.,  1976.,
#           625.,    84.]),
#  array([ 0.02 ,  0.118,  0.216,  0.314,  0.412,  0.51 ,  0.608,  0.706,
#          0.804,  0.902,  1.   ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# Keep getting these errors — need to discuss how to perform this operation without errors

# %%
plt.plot(bike.temp)

# %% [markdown]
# Again, errors are generated — not sure what I'm doing wrong

# %%
sns.boxplot(bike.temp, bike.atemp, vert=False)

# %%
sns.kdeplot(bike.temp)
